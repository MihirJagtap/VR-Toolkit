# %%
from PIL import Image
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
def contrast_stretch(img, inputimg_path, outputimg_path):
    inputImage = Image.open(img).convert('L')
    inputImage.save(inputimg_path)
    outputImage = Image.new('L', inputImage.size)

    width, height = inputImage.size

    minIntensity = 255
    maxInsenity = 0

    for x in range(width):
        for y in range(height):
            intensity = inputImage.getpixel((x,y))

            minIntensity = min(minIntensity, intensity)
            maxInsenity = max(maxInsenity, intensity)

    for x in range(width):
        for y in range(height):
            intensity = inputImage.getpixel((x,y))

            newIntensity = 255 * ((intensity - minIntensity) / (maxInsenity - minIntensity))
            outputImage.putpixel((x,y), int(newIntensity))

    outputImage.save(outputimg_path)

# %%
img = '../images/contrast_examples/reindeer_input.png'
inputimg_path = '../images/contrast_examples/reindeer_input.png'
outputimg_path = '../images/contrast_examples/reindeer_output.png'

contrast_stretch(img, inputimg_path, outputimg_path)

# %%
img = '../images/contrast_examples/scene_input.png'
inputimg_path = '../images/contrast_examples/scene_input.png'
outputimg_path = '../images/contrast_examples/scene_output.png'

contrast_stretch(img, inputimg_path, outputimg_path)

# %%
img = '../images/contrast_examples/fruits_input.png'
inputimg_path = '../images/contrast_examples/fruits_input.png'
outputimg_path = '../images/contrast_examples/fruits_output.png'

contrast_stretch(img, inputimg_path, outputimg_path)

# %%
img = '../images/contrast_examples/test.png'
inputimg_path = '../images/contrast_examples/test_input.png'
outputimg_path = '../images/contrast_examples/test_output.png'

contrast_stretch(img, inputimg_path, outputimg_path)

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
f.suptitle("Contrasting by Stretching (Reindeer)", fontsize=15)

img = cv.imread('../images/contrast_examples/reindeer_input.png', 0)
hist, bins = np.histogram(img.flatten(), 256, [0, 256])
normcdf = (hist.cumsum()/hist.cumsum().max()) * hist.max()

ax1.plot(normcdf, color = 'blue')
ax1.hist(img.flatten(), 256, [0, 256], color='orange')
ax1.set_xlim([0, 256])
ax1.title.set_text("Histogram Before Stretching")
ax1.legend(('CDF', 'Histogram'))

img = cv.imread('../images/contrast_examples/reindeer_output.png', 0)
hist, bins = np.histogram(img.flatten(), 256, [0, 256])
normcdf = (hist.cumsum()/hist.cumsum().max()) * hist.max()

ax2.plot(normcdf, color = 'blue')
ax2.hist(img.flatten(), 256, [0, 256], color='orange')
ax2.set_xlim([0, 256])
ax2.title.set_text("Histogram After Stretching")
ax2.legend(('CDF', 'Histogram'))

plt.savefig("../images/contrast_histograms/reindeer.png")

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
f.suptitle("Contrasting by Stretching (Scenery)", fontsize=15)

img = cv.imread('../images/contrast_examples/scene_input.png', 0)
hist, bins = np.histogram(img.flatten(), 256, [0, 256])
normcdf = (hist.cumsum()/hist.cumsum().max()) * hist.max()

ax1.plot(normcdf, color = 'blue')
ax1.hist(img.flatten(), 256, [0, 256], color='orange')
ax1.title.set_text("Histogram Before Stretching")
ax1.set_xlim([0, 256])
ax1.legend(('CDF', 'Histogram'))

img = cv.imread('../images/contrast_examples/scene_output.png', 0)
hist, bins = np.histogram(img.flatten(), 256, [0, 256])
normcdf = (hist.cumsum()/hist.cumsum().max()) * hist.max()

ax2.plot(normcdf, color = 'blue')
ax2.hist(img.flatten(), 256, [0, 256], color='orange')
ax2.title.set_text("Histogram After Stretching")
ax2.set_xlim([0, 256])
ax2.legend(('CDF', 'Histogram'))

plt.savefig("../images/contrast_histograms/scenery.png")

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
f.suptitle("Contrasting by Stretching (Fruits)", fontsize=15)

img = cv.imread('../images/contrast_examples/fruits_input.png', 0)
hist, bins = np.histogram(img.flatten(), 256, [0, 256])
normcdf = (hist.cumsum()/hist.cumsum().max()) * hist.max()

ax1.plot(normcdf, color = 'blue')
ax1.hist(img.flatten(), 256, [0, 256], color='orange')
ax1.title.set_text("Histogram Before Stretching")
ax1.set_xlim([0, 256])
ax1.legend(('CDF', 'Histogram'))

img = cv.imread('../images/contrast_examples/fruits_output.png', 0)
hist, bins = np.histogram(img.flatten(), 256, [0, 256])
normcdf = (hist.cumsum()/hist.cumsum().max()) * hist.max()

ax2.plot(normcdf, color = 'blue')
ax2.hist(img.flatten(), 256, [0, 256], color='orange')
ax2.title.set_text("Histogram After Stretching")
ax2.set_xlim([0, 256])
ax2.legend(('CDF', 'Histogram'))

plt.savefig("../images/contrast_histograms/fruits.png")

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
f.suptitle("Contrasting by Stretching (Text)", fontsize=15)


img = cv.imread('../images/contrast_examples/test_input.png', 0)
hist, bins = np.histogram(img.flatten(), 256, [0, 256])
normcdf = (hist.cumsum()/hist.cumsum().max()) * hist.max()

ax1.plot(normcdf, color = 'blue')
ax1.hist(img.flatten(), 256, [0, 256], color='orange')
ax1.title.set_text("Histogram Before Stretching")
ax1.set_xlim([0, 256])
ax1.legend(('CDF', 'Histogram'))

img = cv.imread('../images/contrast_examples/test_output.png', 0)
hist, bins = np.histogram(img.flatten(), 256, [0, 256])
normcdf = (hist.cumsum()/hist.cumsum().max()) * hist.max()

ax2.plot(normcdf, color = 'blue')
ax2.hist(img.flatten(), 256, [0, 256], color='orange')
ax2.title.set_text("Histogram After Stretching")
ax2.set_xlim([0, 256])
ax2.legend(('CDF', 'Histogram'))

plt.savefig("../images/contrast_histograms/text.png")
# Out:
# libpng warning: iCCP: profile 'ICC Profile': 'RGB ': RGB color space not permitted on grayscale PNG
